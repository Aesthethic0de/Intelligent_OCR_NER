# %%
import numpy as np
import pandas as pd
import cv2
import PIL
import pytesseract

# %%
img_cv = cv2.imread("./Data/000.jpeg")
cv2.imshow("BusinessCard", img_cv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_pl = PIL.Image.open("./Data/000.jpeg")

# %%
type(img_cv)
# Out:
# numpy.ndarray

# %%
type(img_pl)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_pl
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1800x1200>

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
text_cv = pytesseract.image_to_string(img_cv)

# %%
print(text_cv)
# Out:
# ‘. 040-4852 8881, 90309 52549
# Fi /laurelsoverseaseducation
#
# “@: LAURELS
#
# OVERSEAS EDUCATIONAL CONSULTANCY PVT. LTD.
#
# Ir. Sa
# | im <
# U.K
#
# AUSTRALIA CANADA IRELAND
#
# ©) www.laurelseducation.com )%info@laurelseducation.com

# %%
text_pl = pytesseract.image_to_string(img_pl)
print(text_pl)
# Out:
# \. 040-4852 8881, 90309 52549
# Fi /laurelsoverseaseducation
#
# “@: LAURELS
#
# OVERSEAS EDUCATIONAL CONSULTANCY PVT. LTD.
#
# er, Sa
# mw | |
# U.K
#
# AUSTRALIA CANADA IRELAND
#
# ©) www.laurelseducation.com )%info@laurelseducation.com

# %%
data = pytesseract.image_to_data(img_pl)

# %%
print(data)
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	1800	1200	-1
# 2	1	1	0	0	0	0	0	1800	1	-1
# 3	1	1	1	0	0	0	0	1800	1	-1
# 4	1	1	1	1	0	0	0	1800	1	-1
# 5	1	1	1	1	1	0	0	1800	1	95.000000
# 2	1	2	0	0	0	998	57	699	124	-1
# 3	1	2	1	0	0	998	57	699	124	-1
# 4	1	2	1	1	0	998	57	699	57	-1
# 5	1	2	1	1	1	998	57	41	50	0.000000	\.
# 5	1	2	1	1	2	1055	58	209	46	96.802910	040-4852
# 5	1	2	1	1	3	1280	58	118	56	96.712875	8881,
# 5	1	2	1	1	4	1413	58	135	46	96.341454	90309
# 5	1	2	1	1	5	1563	58	134	46	96.596107	52549
# 4	1	2	1	2	0	1044	131	652	50	-1
# 5	1	2	1	2	1	1040	127	54	66	76.076141	Fi
# 5	1	2	1	2	2	1103	131	593	50	76.076141	/laurelsoverseaseducation
# 2	1	3	0	0	0	85	203	1630	280	-1
# 3	1	3	1	0	0	85	203	1630	280	-1
# 4	1	3	1	1	0	85	203	1630	280	-1
# 5	1	3	1	1	1	85	203	369	259	31.605957	“@:
# 5	1	3	1	1	2	538	238	1177	245	96.492188	LAURELS
# 2	1	4	0	0	0	108	555	1588	82	-1
# 3	1	4	1	0	0	108	555	1588	82	-1
# 4	1	4	1	1	0	108	555	1588	82	-1
# ...

# %%
data.split("\n")
# Out:
# ['level\tpage_num\tblock_num\tpar_num\tline_num\tword_num\tleft\ttop\twidth\theight\tconf\ttext',
#  '1\t1\t0\t0\t0\t0\t0\t0\t1800\t1200\t-1\t',
#  '2\t1\t1\t0\t0\t0\t0\t0\t1800\t1\t-1\t',
#  '3\t1\t1\t1\t0\t0\t0\t0\t1800\t1\t-1\t',
#  '4\t1\t1\t1\t1\t0\t0\t0\t1800\t1\t-1\t',
#  '5\t1\t1\t1\t1\t1\t0\t0\t1800\t1\t95.000000\t ',
#  '2\t1\t2\t0\t0\t0\t998\t57\t699\t124\t-1\t',
#  '3\t1\t2\t1\t0\t0\t998\t57\t699\t124\t-1\t',
#  '4\t1\t2\t1\t1\t0\t998\t57\t699\t57\t-1\t',
#  '5\t1\t2\t1\t1\t1\t998\t57\t41\t50\t0.000000\t\\.',
#  '5\t1\t2\t1\t1\t2\t1055\t58\t209\t46\t96.802910\t040-4852',
#  '5\t1\t2\t1\t1\t3\t1280\t58\t118\t56\t96.712875\t8881,',
#  '5\t1\t2\t1\t1\t4\t1413\t58\t135\t46\t96.341454\t90309',
#  '5\t1\t2\t1\t1\t5\t1563\t58\t134\t46\t96.596107\t52549',
#  '4\t1\t2\t1\t2\t0\t1044\t131\t652\t50\t-1\t',
#  '5\t1\t2\t1\t2\t1\t1040\t127\t54\t66\t76.076141\tFi',
#  '5\t1\t2\t1\t2\t2\t1103\t131\t593\t50\t76.076141\t/laurelsoverseaseducation',
# ...

# %%
dataList = list(map(lambda x : x.split("\t"),data.split("\n")))

# %%
dataList
# Out:
# [['level',
#   'page_num',
#   'block_num',
#   'par_num',
#   'line_num',
#   'word_num',
#   'left',
#   'top',
#   'width',
#   'height',
#   'conf',
#   'text'],
#  ['1', '1', '0', '0', '0', '0', '0', '0', '1800', '1200', '-1', ''],
#  ['2', '1', '1', '0', '0', '0', '0', '0', '1800', '1', '-1', ''],
#  ['3', '1', '1', '1', '0', '0', '0', '0', '1800', '1', '-1', ''],
#  ['4', '1', '1', '1', '1', '0', '0', '0', '1800', '1', '-1', ''],
#  ['5', '1', '1', '1', '1', '1', '0', '0', '1800', '1', '95.000000', ' '],
#  ['2', '1', '2', '0', '0', '0', '998', '57', '699', '124', '-1', ''],
#  ['3', '1', '2', '1', '0', '0', '998', '57', '699', '124', '-1', ''],
#  ['4', '1', '2', '1', '1', '0', '998', '57', '699', '57', '-1', ''],
#  ['5', '1', '2', '1', '1', '1', '998', '57', '41', '50', '0.000000', '\\.'],
#  ['5',
#   '1',
#   '2',
#   '1',
#   '1',
#   '2',
#   '1055',
#   '58',
#   '209',
#   '46',
#   '96.802910',
#   '040-4852'],
#  ['5',
#   '1',
#   '2',
#   '1',
#   '1',
#   '3',
# ...

# %%
df = pd.DataFrame(dataList[1:],columns=dataList[0])

# %%
df
# Out:
#    level page_num block_num par_num line_num word_num  left   top width  \
# 0      1        1         0       0        0        0     0     0  1800
# 1      2        1         1       0        0        0     0     0  1800
# 2      3        1         1       1        0        0     0     0  1800
# 3      4        1         1       1        1        0     0     0  1800
# 4      5        1         1       1        1        1     0     0  1800
# ..   ...      ...       ...     ...      ...      ...   ...   ...   ...
# 70     2        1        12       0        0        0     0  1058  1800
# 71     3        1        12       1        0        0     0  1058  1800
# 72     4        1        12       1        1        0     0  1058  1800
# 73     5        1        12       1        1        1     0  1058  1800
# 74           None      None    None     None     None  None  None  None
#
#    height       conf  text
# 0    1200         -1
# 1       1         -1
# 2       1         -1
# ...

# %%
df.head()
# Out:
#   level page_num block_num par_num line_num word_num left top width height  \
# 0     1        1         0       0        0        0    0   0  1800   1200
# 1     2        1         1       0        0        0    0   0  1800      1
# 2     3        1         1       1        0        0    0   0  1800      1
# 3     4        1         1       1        1        0    0   0  1800      1
# 4     5        1         1       1        1        1    0   0  1800      1
#
#         conf text
# 0         -1
# 1         -1
# 2         -1
# 3         -1
# 4  95.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   level      75 non-null     object
#  1   page_num   74 non-null     object
#  2   block_num  74 non-null     object
#  3   par_num    74 non-null     object
#  4   line_num   74 non-null     object
#  5   word_num   74 non-null     object
#  6   left       74 non-null     object
#  7   top        74 non-null     object
#  8   width      74 non-null     object
#  9   height     74 non-null     object
#  10  conf       74 non-null     object
#  11  text       74 non-null     object
# dtypes: object(12)
# memory usage: 7.2+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 0 to 73
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   level      74 non-null     object
#  1   page_num   74 non-null     object
#  2   block_num  74 non-null     object
#  3   par_num    74 non-null     object
#  4   line_num   74 non-null     object
#  5   word_num   74 non-null     object
#  6   left       74 non-null     object
#  7   top        74 non-null     object
#  8   width      74 non-null     object
#  9   height     74 non-null     object
#  10  conf       74 non-null     object
#  11  text       74 non-null     object
# dtypes: object(12)
# memory usage: 7.5+ KB

# %%
df.columns
# Out:
# Index(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num',
#        'left', 'top', 'width', 'height', 'conf', 'text'],
#       dtype='object')

# %%
col_int = ['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num',
       'left', 'top', 'width', 'height', 'conf']
df[col_int] = df[col_int].astype(float).astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 0 to 73
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   level      74 non-null     int64
#  1   page_num   74 non-null     int64
#  2   block_num  74 non-null     int64
#  3   par_num    74 non-null     int64
#  4   line_num   74 non-null     int64
#  5   word_num   74 non-null     int64
#  6   left       74 non-null     int64
#  7   top        74 non-null     int64
#  8   width      74 non-null     int64
#  9   height     74 non-null     int64
#  10  conf       74 non-null     int64
#  11  text       74 non-null     object
# dtypes: int64(11), object(1)
# memory usage: 7.5+ KB

# %%
df.dtypes
# Out:
# level         int64
# page_num      int64
# block_num     int64
# par_num       int64
# line_num      int64
# word_num      int64
# left          int64
# top           int64
# width         int64
# height        int64
# conf          int64
# text         object
# dtype: object

# %%
image = img_cv.copy()
level = "word"
for l,x,y,w,h,c,txt in df[["level", "left", "top", "width", "height", "conf", "text"]].values:
    if level == "page":
        if l == 1:
            cv2.rectangle(image,(x,y),(x+w,y+h), (0,0,0), 2)
        else:
            continue
    elif level == "block":
        if l == 2:
            cv2.rectangle(image,(x,y),(x+w,y+h), (255,0,0), 2)
        else:
            continue
    elif level == "para":
        if l == 3:
             cv2.rectangle(image,(x,y),(x+w,y+h), (0,255,0), 2)
        else:
            continue
    elif level == "line":
        if l == 4:
            cv2.rectangle(image,(x,y),(x+w,y+h), (0,0,255), 2)
        else:
            continue
    elif level == "word":
        if l == 5:
            cv2.rectangle(image,(x,y),(x+w,y+h), (0,255,0), 2)
            cv2.putText(image,txt,(x,y), cv2.FONT_HERSHEY_PLAIN,1,(255,0,0))
        else:
            continue

cv2.imshow("bounding_box", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import os
from glob import glob
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
imgPaths =  glob("./Data/*.jpeg")

# %%
allBusinessCard = pd.DataFrame(columns=['id','text'])

for imgPath in  tqdm(imgPaths,desc='BusinessCard'):
    _, filename = os.path.split(imgPath)
    image = cv2.imread(imgPath)
    data = pytesseract.image_to_data(image)
    dataList = list(map(lambda x: x.split('\t'),data.split('\n')))
    df = pd.DataFrame(dataList[1:],columns=dataList[0])
    df.dropna(inplace=True)
    df['conf'] = df['conf'].astype(float)
    useFulData = df.query('conf >= 30')
    businessCard = pd.DataFrame()
    businessCard['text'] = useFulData['text']
    businessCard['id'] = filename
    allBusinessCard = pd.concat((allBusinessCard,businessCard))
# Out:
# BusinessCard: 100%|██████████| 293/293 [01:59<00:00,  2.45it/s]

# %%
allBusinessCard.to_csv("buinesscard.csv", index=False)

# %%
import numpy as np
import pandas as pd
import string
import re

# %%
with open("./businessCard_tab.txt", mode="r", encoding="utf-8", errors="ignore") as f:
    text = f.read()

# %%
print(text)
# Out:
# id	text	tag
# 000.jpeg	 	O
# 000.jpeg	.	O
# 000.jpeg	040-4852	B-PHONE
# 000.jpeg	"8881,"	I-PHONE
# 000.jpeg	90309	B-PHONE
# 000.jpeg	52549	I-PHONE
# 000.jpeg	Fi	O
# 000.jpeg	/laurelsoverseaseducation	O
# 000.jpeg	@:	O
# 000.jpeg	LAURELS	B-ORG
# 000.jpeg	OVERSEAS	I-ORG
# 000.jpeg	EDUCATIONAL	I-ORG
# 000.jpeg	CONSULTANCY	I-ORG
# 000.jpeg	PVT.	I-ORG
# 000.jpeg	LTD.	I-ORG
# 000.jpeg	Sea	O
# 000.jpeg	|	O
# 000.jpeg	U.K	O
# 000.jpeg	AUSTRALIA	O
# 000.jpeg	CANADA	O
# 000.jpeg	IRELAND	O
# 000.jpeg	 	O
# 000.jpeg	 	O
# 000.jpeg	 	O
# 000.jpeg	 	O
# 000.jpeg	 	O
# 000.jpeg	 	O
# 000.jpeg	www.laurelseducation.com	B-WEB
# 000.jpeg	)%info@laurelseducation.com	B-EMAIL
# 000.jpeg	 	O
# 001.jpeg	john	B-NAME
# 001.jpeg	smith	I-NAME
# 001.jpeg	marketing	B-DES
# 001.jpeg	manager	I-DES
# 001.jpeg	web:	O
# 001.jpeg	www.psdgraphics.com	B-WEB
# 001.jpeg	phone:	O
# 001.jpeg	123-456-7890	B-PHONE
# 001.jpeg	mail:	O
# 001.jpeg	email@psdgraphics.com	B-EMAIL
# 002.jpeg	    	O
# 002.jpeg	   	O
# 002.jpeg	Sau	O
# ...

# %%
data = list(map(lambda x : x.split("\t"), text.split("\n")))

# %%
df = pd.DataFrame(data=data[1:], columns=data[0])

# %%
df
# Out:
#              id       text      tag
# 0      000.jpeg                   O
# 1      000.jpeg          .        O
# 2      000.jpeg   040-4852  B-PHONE
# 3      000.jpeg    "8881,"  I-PHONE
# 4      000.jpeg      90309  B-PHONE
# ...         ...        ...      ...
# 10441  290.jpeg    Richard   B-NAME
# 10442  290.jpeg  Pretorius   I-NAME
# 10443  290.jpeg                   O
# 10444  290.jpeg   Director    B-DES
# 10445                 None     None
#
# [10446 rows x 3 columns]

# %% [markdown]
# # Cleaning Text

# %%
whitespace = string.whitespace
punctuation = "!#$%&\'()*+:;<=>?[\\]^`{|}~"
tableWhitespace = str.maketrans('','',whitespace)
tablePunctuation = str.maketrans('','',punctuation)
def cleanText(txt):
    text = str(txt)
    text = text.lower()
    removewhitespace = text.translate(tableWhitespace)
    removepunctuation = removewhitespace.translate(tablePunctuation)
    
    return str(removepunctuation)

# %%
df["text"] = df["text"].apply(clean_text)

# %%
dataClean = df.query("text != '' ")
dataClean.dropna(inplace=True)

# %%
dataClean
# Out:
#              id          text      tag
# 1      000.jpeg             .        O
# 2      000.jpeg       0404852  B-PHONE
# 3      000.jpeg          8881  I-PHONE
# 4      000.jpeg         90309  B-PHONE
# 5      000.jpeg         52549  I-PHONE
# ...         ...           ...      ...
# 10437  290.jpeg             p        O
# 10439  290.jpeg  srmrrisurres    B-ORG
# 10441  290.jpeg       richard   B-NAME
# 10442  290.jpeg     pretorius   I-NAME
# 10444  290.jpeg      director    B-DES
#
# [8088 rows x 3 columns]

# %% [markdown]
# #  Convert data to space format

# %%
group = dataClean.groupby(by="id")

# %%
cards = group.groups.keys()
cards
# Out:
# dict_keys(['000.jpeg', '001.jpeg', '002.jpeg', '003.jpeg', '004.jpeg', '007.jpeg', '008.jpeg', '009.jpeg', '010.jpeg', '011.jpeg', '012.jpeg', '013.jpeg', '014.jpeg', '015.jpeg', '016.jpeg', '017.jpeg', '018.jpeg', '020.jpeg', '021.jpeg', '022.jpeg', '023.jpeg', '024.jpeg', '025.jpeg', '027.jpeg', '028.jpeg', '030.jpeg', '031.jpeg', '032.jpeg', '033.jpeg', '034.jpeg', '035.jpeg', '036.jpeg', '037.jpeg', '038.jpeg', '039.jpeg', '040.jpeg', '041.jpeg', '042.jpeg', '043.jpeg', '044.jpeg', '045.jpeg', '047.jpeg', '048.jpeg', '049.jpeg', '050.jpeg', '051.jpeg', '052.jpeg', '053.jpeg', '054.jpeg', '055.jpeg', '056.jpeg', '057.jpeg', '058.jpeg', '059.jpeg', '060.jpeg', '061.jpeg', '062.jpeg', '063.jpeg', '064.jpeg', '065.jpeg', '066.jpeg', '067.jpeg', '068.jpeg', '069.jpeg', '070.jpeg', '071.jpeg', '072.jpeg', '073.jpeg', '074.jpeg', '075.jpeg', '076.jpeg', '078.jpeg', '079.jpeg', '080.jpeg', '081.jpeg', '082.jpeg', '083.jpeg', '084.jpeg', '085.jpeg', '086.jpeg', '087.jpeg', '088.jpeg', '08
# ...

# %%
allCardsData = []
for i in cards:
    carData = []
    grouparray = group.get_group(i)[["text","tag"]].values
    content = ''
    annotations = {"entities" : []}
    start = 0
    end = 0
    for text, label in grouparray:
        text = str(text)
        stringLength = len(text) + 1
        start = end
        end = start + stringLength
        if label != "O":
            annot = (start,end-1, label)
            annotations["entities"].append(annot)
        content = content + text + ' '

    
    carData = (content, annotations)
    allCardsData.append(carData)

# %%
allCardsData
# Out:
# [('. 0404852 8881 90309 52549 fi /laurelsoverseaseducation @ laurels overseas educational consultancy pvt. ltd. sea u.k australia canada ireland www.laurelseducation.com info@laurelseducation.com ',
#   {'entities': [(2, 9, 'B-PHONE'),
#     (10, 14, 'I-PHONE'),
#     (15, 20, 'B-PHONE'),
#     (21, 26, 'I-PHONE'),
#     (58, 65, 'B-ORG'),
#     (66, 74, 'I-ORG'),
#     (75, 86, 'I-ORG'),
#     (87, 98, 'I-ORG'),
#     (99, 103, 'I-ORG'),
#     (104, 108, 'I-ORG'),
#     (142, 166, 'B-WEB'),
#     (167, 192, 'B-EMAIL')]}),
#  ('john smith marketing manager web www.psdgraphics.com phone 1234567890 mail email@psdgraphics.com ',
#   {'entities': [(0, 4, 'B-NAME'),
#     (5, 10, 'I-NAME'),
#     (11, 20, 'B-DES'),
#     (21, 28, 'I-DES'),
#     (33, 52, 'B-WEB'),
#     (59, 69, 'B-PHONE'),
#     (75, 96, 'B-EMAIL')]}),
#  ('sau 0 98489 24441 dy 08672 224441 /enkateswapa wie ',
#   {'entities': [(6, 11, 'B-PHONE'), (12, 17, 'I-PHONE'), (34, 46, 'B-ORG')]}),
# ...

# %% [markdown]
# # Split Data into Train and Test Set

# %%
import random

# %%
random.shuffle(allCardsData)

# %%
len(allCardsData)
# Out:
# 267

# %%
TrainData = allCardsData[:240]
TestData = allCardsData[240:]

# %%
import pickle
pickle.dump(TrainData,open('TrainData.pickle',mode='wb'))
pickle.dump(TestData,open('TestData.pickle',mode='wb'))

# %% [markdown]
# # Predictions after training

# %%
import numpy as np
import pandas as pd
import cv2
import pytesseract
from glob import glob
import spacy
import re
import string

# %%
def cleanText(txt):
    whitespace = string.whitespace
    punctuation = "!#$%&\'()*+:;<=>?[\\]^`{|}~"
    tableWhitespace = str.maketrans('','',whitespace)
    tablePunctuation = str.maketrans('','',punctuation)
    text = str(txt)
    text = text.lower()
    removewhitespace = text.translate(tableWhitespace)
    removepunctuation = removewhitespace.translate(tablePunctuation)
    return str(removepunctuation)

# %%
model_ner = spacy.load("output\model-best")

# %%
image = cv2.imread("test_image.jpg")

# %%
text = pytesseract.image_to_data(image)

# %%
print(text)
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	1065	616	-1
# 2	1	1	0	0	0	3	0	1062	5	-1
# 3	1	1	1	0	0	3	0	1062	5	-1
# 4	1	1	1	1	0	3	0	1062	5	-1
# 5	1	1	1	1	1	3	0	1062	5	95.000000
# 2	1	2	0	0	0	47	44	8	119	-1
# 3	1	2	1	0	0	47	44	8	119	-1
# 4	1	2	1	1	0	47	44	8	119	-1
# 5	1	2	1	1	1	47	44	8	119	95.000000
# 2	1	3	0	0	0	46	53	979	156	-1
# 3	1	3	1	0	0	722	53	303	28	-1
# 4	1	3	1	1	0	722	53	303	28	-1
# 5	1	3	1	1	1	722	53	64	28	90.167198	Cell
# 5	1	3	1	1	2	802	60	5	20	90.167198	:
# 5	1	3	1	1	3	822	53	203	28	96.483879	8099948528
# 3	1	3	2	0	0	55	55	970	112	-1
# 4	1	3	2	1	0	55	55	970	89	-1
# 5	1	3	2	1	1	55	55	85	89	47.185547	(Ga)
# 5	1	3	2	1	2	822	95	203	28	96.435081	8466045457
# 4	1	3	2	2	0	593	136	432	31	-1
# 5	1	3	2	2	1	593	136	93	25	89.289780	email
# 5	1	3	2	2	2	679	132	11	40	86.249245	:
# 5	1	3	2	2	3	709	136	316	31	86.249245	lictsrikant@gmail.com
# 3	1	3	3	0	0	46	151	979	58	-1
# 4	1	3	3	1	0	46	151	979	58	-1
# ...

# %%
tessList = list(map(lambda x:x.split('\t'), text.split('\n')))
df = pd.DataFrame(tessList[1:],  columns=tessList[0])
df.dropna(inplace=True)
df["text"] = df["text"].apply(cleanText)
df_clean = df.query('text != "" ')
content = " ".join([w for w in df_clean["text"]])

# %%
doc = model_ner(content)

# %%
from spacy import displacy
displacy.serve(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">cell
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8099948528
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  ga
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8466045457
# ...

# %% [markdown]
# # Tagging

# %%
doc_json = doc.to_json()

# %%
doc_text = doc_json["text"]
dataframe_tag = pd.DataFrame(doc_json["tokens"])
dataframe_tag["tokens"] = dataframe_tag[["start", "end"]].apply(
    lambda x : doc_text[x[0]:x[1]], axis=1)

# %%
dataframe_tag.head()
# Out:
#    id  start  end      tokens
# 0   0      0    4        cell
# 1   1      5   15  8099948528
# 2   2     16   18          ga
# 3   3     19   29  8466045457
# 4   4     30   35       email

# %%
right_table = pd.DataFrame(doc_json['ents'])[['start','label']]
datafram_tokens = pd.merge(dataframe_tag,right_table,how='left',on='start')

# %%
datafram_tokens.fillna("O", inplace=True)

# %%
datafram_tokens
# Out:
#     id  start  end      tokens    label
# 0    0      0    4        cell        O
# 1    1      5   15  8099948528  B-PHONE
# 2    2     16   18          ga        O
# 3    3     19   29  8466045457  B-PHONE
# 4    4     30   35       email        O
# ..  ..    ...  ...         ...      ...
# 58  58    448  455     promote        O
# 59  59    456  460        your        O
# 60  60    461  469    business        O
# 61  61    470  476      online        O
# 62  62    477  481        pybo        O
#
# [63 rows x 5 columns]

# %% [markdown]
# # Join labels to df_clean

# %%
df_clean["end"] = df_clean["text"].apply(lambda x : len(x) + 1).cumsum() -1
df_clean["start"] = df_clean[["text", "end"]].apply(lambda x : x[1] - len(x[0]),axis=1)

# %%
df_clean
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 12     5        1         3       1        1        1  722   53    64     28
# 14     5        1         3       1        1        3  822   53   203     28
# 17     5        1         3       2        1        1   55   55    85     89
# 18     5        1         3       2        1        2  822   95   203     28
# 20     5        1         3       2        2        1  593  136    93     25
# 22     5        1         3       2        2        3  709  136   316     31
# 25     5        1         3       3        1        1   46  170    33     14
# 26     5        1         3       3        1        2   85  151    92     42
# 27     5        1         3       3        1        3  183  170   117     14
# 28     5        1         3       3        1        4  306  170    20     14
# 29     5        1         3       3        1        5  332  170    42     14
# ...

# %%
datafram_tokens
# Out:
#     id  start  end      tokens    label
# 0    0      0    4        cell        O
# 1    1      5   15  8099948528  B-PHONE
# 2    2     16   18          ga        O
# 3    3     19   29  8466045457  B-PHONE
# 4    4     30   35       email        O
# ..  ..    ...  ...         ...      ...
# 58  58    448  455     promote        O
# 59  59    456  460        your        O
# 60  60    461  469    business        O
# 61  61    470  476      online        O
# 62  62    477  481        pybo        O
#
# [63 rows x 5 columns]

# %%
dataframe_info = pd.merge(df_clean, datafram_tokens[["start", "tokens", "label"]], how="inner", on="start")

# %%
dataframe_info.head()
# Out:
#   level page_num block_num par_num line_num word_num left  top width height  \
# 0     5        1         3       1        1        1  722   53    64     28
# 1     5        1         3       1        1        3  822   53   203     28
# 2     5        1         3       2        1        1   55   55    85     89
# 3     5        1         3       2        1        2  822   95   203     28
# 4     5        1         3       2        2        1  593  136    93     25
#
#         conf        text  end  start      tokens    label
# 0  90.167198        cell    4      0        cell        O
# 1  96.483879  8099948528   15      5  8099948528  B-PHONE
# 2  47.185547          ga   18     16          ga        O
# 3  96.435081  8466045457   29     19  8466045457  B-PHONE
# 4  89.289780       email   35     30       email        O

# %% [markdown]
# # Bounding Box

# %%
bb_df = dataframe_info.query("label != 'O'")
img = image.copy()

# %%
for x,y,w,h,label in bb_df[["left","top","width","height","label"]].values:
    x = int(x)
    y = int(y)
    w = int(w)
    h = int(h)
    cv2.rectangle(img, (x,y),(x+w, y+h),(0,255,0),2)
    cv2.putText(img, str(label),(x,y),cv2.FONT_HERSHEY_PLAIN,1,(255,0,0),2)
cv2.imshow("Predictions", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
bb_df["label"] = bb_df["label"].apply(lambda x : x[2:])

# %%
class Groupgen():
    def __init__(self):
        self.id = 0
        self.text = ""

    def getgroup(self,text):
        if self.text == text:
            return self.id
        else:
            self.id += 1
            self.text = text
            return self.id
        
groupg = Groupgen()

# %%
bb_df["group"] = bb_df["label"].apply(groupg.getgroup)

# %%
# right and bottom of bounding box
bb_df[['left','top','width','height']] = bb_df[['left','top','width','height']].astype(int)
bb_df['right'] = bb_df['left'] + bb_df['width']
bb_df['bottom'] = bb_df['top'] + bb_df['height']

# %%
bb_df
# Out:
#    level page_num block_num par_num line_num word_num  left  top  width  \
# 1      5        1         3       1        1        3   822   53    203
# 3      5        1         3       2        1        2   822   95    203
# 5      5        1         3       2        2        3   709  136    316
# 6      5        1         3       3        1        1    46  170     33
# 7      5        1         3       3        1        2    85  151     92
# 8      5        1         3       3        1        3   183  170    117
# 9      5        1         3       3        1        4   306  170     20
# 10     5        1         3       3        1        5   332  170     42
# 11     5        1         3       3        1        6   668  166    119
# 12     5        1         3       3        1        7   791  165    162
# 13     5        1         3       3        1        8   958  180     67
# 14     5        1         4       1        1        1   310  228    232
# ...

# %%
col_group = ['left','top','right','bottom','label','tokens','group']
group_tag_img = bb_df[col_group].groupby(by='group')

# %%
group_tag_img

# %%
img_tagging = group_tag_img.agg({
    
    'left':min,
    'right':max,
    'top':min,
    'bottom':max,
    'label':np.unique,
    'tokens':lambda x: " ".join(x)
    
})

# %%
img_tagging
# Out:
#        left  right  top  bottom    label  \
# group
# 1       822   1025   53     123  [PHONE]
# 2       709   1025  136     167  [EMAIL]
# 3        46    374  151     193    [ORG]
# 4       668   1025  165     209  [EMAIL]
# 5       310    755  227     259   [NAME]
# 6       399    669  271     296    [DES]
# 7        47    882  395     427    [ORG]
# 8        46    917  506     533    [WEB]
#
#                                                   tokens
# group
# 1                                  8099948528 8466045457
# 2                                  lictsrikant@gmail.com
# 3                    life insurance corporation of india
# 4                                  seosrika ntht@gmail “
# 5                                    thathineni srikanth
# 6                                      insurance advisor
# 7                    life insurance corporation of india
# 8      lictsrikant8099948528.blogspot.in interviewsin...

# %%
img_bb = image.copy()
for l,r,t,b,label,token in img_tagging.values:
    l = int(l)
    r = int(r)
    t = int(t)
    b = int(b)
    cv2.rectangle(img_bb,(l,t),(r,b),(0,255,0),2)
    cv2.putText(img_bb,label[0],(l,t),cv2.FONT_HERSHEY_PLAIN,1,(255,0,255))
cv2.imshow('Bounding Box BusinessCard',img_bb)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # how to do Parsing?

# %%
def parser(text,label):
    if label == 'PHONE':
        text = text.lower()
        text = re.sub(r'\D','',text)
        
    elif label == 'EMAIL':
        text = text.lower()
        allow_special_char = '@_.\-'
        text = re.sub(r'[^A-Za-z0-9{} ]'.format(allow_special_char),'',text)
        
    elif label == 'WEB':
        text = text.lower()
        allow_special_char = ':/.%#\-'
        text = re.sub(r'[^A-Za-z0-9{} ]'.format(allow_special_char),'',text)
        
    elif label in ('NAME', 'DES'):
        text = text.lower()
        text = re.sub(r'[^a-z ]','',text)
        text = text.title()
        
    elif label == 'ORG':
        text = text.lower()
        text = re.sub(r'[^a-z0-9 ]','',text)
        text = text.title()
        
    return text

# %%
parser("m@gmail.com", "EMAIL")
# Out:
# 'm@gmail.com'

# %% [markdown]
# # Entities

# %%
info_array = dataframe_info[['tokens','label']].values
entities = dict(NAME=[],ORG=[],DES=[],PHONE=[],EMAIL=[],WEB=[])
previous = 'O'

for token, label in info_array:
    bio_tag = label[0]
    label_tag = label[2:]
    text = parser(token,label_tag)
    if bio_tag in ('B','I'):        
        if previous != label_tag:
            entities[label_tag].append(text)          
        else:
            if bio_tag == "B":
                entities[label_tag].append(text)   
            else:
                if label_tag in ("NAME",'ORG','DES'):
                    entities[label_tag][-1] = entities[label_tag][-1] + " " + text   
                else:
                    entities[label_tag][-1] = entities[label_tag][-1] + text
                    
    
    
    previous = label_tag

# %%
entities
# Out:
# {'NAME': ['Thathineni Srikanth'],
#  'ORG': ['Life Insurance Corporation Of India',
#   'Life Insurance Corporation Of India'],
#  'DES': ['Insurance Advisor'],
#  'PHONE': ['8099948528', '8466045457'],
#  'EMAIL': ['lictsrikant@gmail.com', 'seosrikantht@gmail'],
#  'WEB': ['lictsrikant8099948528.blogspot.in',
#   'interviewsinhyderabad.blogspot.in']}

# %%
from utils.predictions import getPredictions
import cv2

img = cv2.imread("242.jpeg")
cv2.namedWindow("original", cv2.WINDOW_NORMAL)
cv2.imshow("original", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import spacy
model_ner = spacy.load("output\model-best")
img_results, entities = getPredictions(img)
print(entities)
resized_image = cv2.resize(img_results, (800, 600))  # Set the width and height you want

# Display the resized image in a window
cv2.namedWindow("Predictions", cv2.WINDOW_NORMAL)
cv2.imshow("Predictions", resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# dr. t. s. reddy senior consultant traffic transportation lea associates south asia pvt. ltd. leadership in consulting engineers planners engineering hl no 1-4-879/54/1a, street no. 8, p lannin g near vijaya bank, lower tank bund, gandhinagar, hyderabad-500080 a.p. india solutions tel 91-40-66747 122 / 66747135 . mobile 91-91778 82230 email tsr@lasaindia.com ————— limmappagari@ymait.com _ alea group company website - www.lasaindia.com
# {'NAME': ['Dr T S Reddy'], 'ORG': ['Lea Associates South Asia Pvt Ltd'], 'DES': ['Senior Consultant'], 'PHONE': ['91122', '66747135', '9182230'], 'EMAIL': ['tsr@lasaindia.com', 'limmappagari@ymait.com'], 'WEB': ['www.lasaindia.com']}

# %%
cv2.imwrite('output_image.jpg', img_results)
# Out:
# True
